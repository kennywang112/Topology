# %%
pip install --verbose git+https://github.com/mrzv/dionysus.git
# Out:
# Note: you may need to restart the kernel to use updated packages.Using pip 24.2 from C:\Users\USER\anaconda3\lib\site-packages\pip (python 3.9)
# ...
#   Cloning https://github.com/mrzv/dionysus.git to c:\users\user\appdata\local\temp\pip-req-build-env1b577
#   Resolved https://github.com/mrzv/dionysus.git to commit dd2ad59538d9b7ba79391299ff48cd829db2b77c
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for dionysus
# Failed to build dionysus
#   Running command git version
#   git version 2.39.1.windows.1
#   Running command git clone --filter=blob:none https://github.com/mrzv/dionysus.git 'C:\Users\USER\AppData\Local\Temp\pip-req-build-env1b577'
#   Cloning into 'C:\Users\USER\AppData\Local\Temp\pip-req-build-env1b577'...
#   Updating files:   0% (2/447)
#   Updating files:   1% (5/447)
#   Updating files:   2% (9/447)
#   Updating files:   3% (14/447)
#   Updating files:   4% (18/447)
# ...
